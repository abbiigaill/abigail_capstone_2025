# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
mp=pd.read_csv('../Notebook/My_Capstone.csv')

# %%
mp
# Out:
#      Case Number Date Last Contacted Missing Age          City  \
# 0       MP124793          2024-05-13    53 Years     Knoxville
# 1        MP40974          2016-12-25    15 Years       Yonkers
# 2       MP120760          2024-01-14    16 Years       Houston
# 3       MP102154          2023-01-29    17 Years   Springfield
# 4       MP113999          2021-11-27    17 Years  Jacksonville
# ...          ...                 ...         ...           ...
# 9154     MP99890          2022-09-25    19 Years        Durham
# 9155    MP123853          2024-04-02    62 Years       Spokane
# 9156     MP95500          2018-08-24    18 Years   New Bedford
# 9157    MP134241          2024-09-27    15 Years        Laurel
# 9158     MP60161          2019-08-31    56 Years         Tulsa
#
#                County State     Sex      Race  Year     First Name/ Last Name  \
# 0                Knox    TN    Male     White  2024            todd zwagerman
# ...

# %%
mp['City_State']= mp['City'] + ', ' + mp['State']

# %%
mp
# Out:
#      Case Number Date Last Contacted Missing Age          City  \
# 0       MP124793          2024-05-13    53 Years     Knoxville
# 1        MP40974          2016-12-25    15 Years       Yonkers
# 2       MP120760          2024-01-14    16 Years       Houston
# 3       MP102154          2023-01-29    17 Years   Springfield
# 4       MP113999          2021-11-27    17 Years  Jacksonville
# ...          ...                 ...         ...           ...
# 9154     MP99890          2022-09-25    19 Years        Durham
# 9155    MP123853          2024-04-02    62 Years       Spokane
# 9156     MP95500          2018-08-24    18 Years   New Bedford
# 9157    MP134241          2024-09-27    15 Years        Laurel
# 9158     MP60161          2019-08-31    56 Years         Tulsa
#
#                County State     Sex      Race  Year     First Name/ Last Name  \
# 0                Knox    TN    Male     White  2024            todd zwagerman
# ...

# %%
mp['County_State']= mp['County'] + ', ' + mp['State']

# %%
##TOP 5 CITIES

# %%
mp['City_State'].value_counts()
# Out:
# City_State
# Dallas, TX            327
# Houston, TX           292
# Los Angeles, CA       206
# Memphis, TN           142
# McAllen, TX           123
#                      ...
# San Ysidro, CA          1
# Cumberland Gap, TN      1
# Worcester, MA           1
# Lake Stevens, WA        1
# Hawi, HI                1
# Name: count, Length: 3387, dtype: int64

# %%
mp["age"] = (
    mp["Missing Age"]
      .str.replace(r"\s*years?\s*$", "", regex=True, case=False)
      .str.replace(r"\s*yrs?\s*$", "", regex=True, case=False)
      .str.strip()
)

# %%
mp
# Out:
#      Case Number Date Last Contacted Missing Age          City  \
# 0       MP124793          2024-05-13    53 Years     Knoxville
# 1        MP40974          2016-12-25    15 Years       Yonkers
# 2       MP120760          2024-01-14    16 Years       Houston
# 3       MP102154          2023-01-29    17 Years   Springfield
# 4       MP113999          2021-11-27    17 Years  Jacksonville
# ...          ...                 ...         ...           ...
# 9154     MP99890          2022-09-25    19 Years        Durham
# 9155    MP123853          2024-04-02    62 Years       Spokane
# 9156     MP95500          2018-08-24    18 Years   New Bedford
# 9157    MP134241          2024-09-27    15 Years        Laurel
# 9158     MP60161          2019-08-31    56 Years         Tulsa
#
#                County State     Sex      Race  Year     First Name/ Last Name  \
# 0                Knox    TN    Male     White  2024            todd zwagerman
# ...

# %%
mp["age"] = pd.to_numeric(mp["age"], errors="coerce")

# %%
bins = [0, 17, 34, 54, 150] 
labels = ["0-17", "18-34", "35-54", "55+"]

# %%
mp["age"] = pd.cut(mp["age"], bins=bins, labels=labels, include_lowest=True)

# %%
mp
# Out:
#      Case Number Date Last Contacted Missing Age          City  \
# 0       MP124793          2024-05-13    53 Years     Knoxville
# 1        MP40974          2016-12-25    15 Years       Yonkers
# 2       MP120760          2024-01-14    16 Years       Houston
# 3       MP102154          2023-01-29    17 Years   Springfield
# 4       MP113999          2021-11-27    17 Years  Jacksonville
# ...          ...                 ...         ...           ...
# 9154     MP99890          2022-09-25    19 Years        Durham
# 9155    MP123853          2024-04-02    62 Years       Spokane
# 9156     MP95500          2018-08-24    18 Years   New Bedford
# 9157    MP134241          2024-09-27    15 Years        Laurel
# 9158     MP60161          2019-08-31    56 Years         Tulsa
#
#                County State     Sex      Race  Year     First Name/ Last Name  \
# 0                Knox    TN    Male     White  2024            todd zwagerman
# ...

# %%
mp.to_csv('My_Capstone.csv', index=False)
